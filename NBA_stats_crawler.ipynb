# %%
import pandas as pd

for table in pd.read_html('https://www.nba.com/players'):
    table.to_csv('NBA_data.csv',encoding = 'utf8', header = 1, index=True)

# %%
data = pd.read_csv('NBA_data.csv')
data.head()
# Out:
#    Unnamed: 0            Player Team  Number Position Height   Weight  \
# 0           0   PreciousAchiuwa  MIA       5        F    6-8  225 lbs
# 1           1       JaylenAdams  MIL       6        G    6-0  225 lbs
# 2           2       StevenAdams  NOP      12        C   6-11  265 lbs
# 3           3        BamAdebayo  MIA      13      C-F    6-9  255 lbs
# 4           4  LaMarcusAldridge  SAS      12      C-F   6-11  250 lbs
#
#      Last Attended      Country
# 0          Memphis      Nigeria
# 1  St. Bonaventure          USA
# 2       Pittsburgh  New Zealand
# 3         Kentucky          USA
# 4            Texas          USA
